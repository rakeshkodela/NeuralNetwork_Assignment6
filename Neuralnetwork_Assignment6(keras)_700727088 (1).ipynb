# %%
import pandas
from keras.models import Sequential
from keras.layers.core import Dense, Activation

from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# %%
# load dataset
dataset = pd.read_csv("diabetes.csv", header=None).values

dataset.shape
# Out:
# (768, 9)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_first_nn = Sequential() # create model
my_first_nn.add(Dense(20, input_dim=8, activation='relu')) # hidden layer
my_first_nn.add(Dense(4, activation='relu')) # hidden layer
my_first_nn.add(Dense(1, activation='sigmoid')) # output layer
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
my_first_nn.summary()
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 3ms/step - loss: 2.0462 - acc: 0.6615
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7935 - acc: 0.6615
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7163 - acc: 0.6615
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6878 - acc: 0.6562
# Epoch 5/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6733 - acc: 0.6528
# Epoch 6/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6659 - acc: 0.6580
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6608 - acc: 0.6615
# Epoch 8/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6576 - acc: 0.6615
# Epoch 9/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6531 - acc: 0.6615
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6501 - acc: 0.6615
# Epoch 11/100
# ...

# %%
my_first_nn.evaluate(X_test, Y_test)

# %% [markdown]
# Add more Dense layers to the existing code and check how the accuracy changes.

# %%
dense_nn = Sequential() # create model
dense_nn.add(Dense(60, input_dim=8, activation='relu')) # hidden layer
dense_nn.add(Dense(80, activation='relu')) # hidden layer
dense_nn.add(Dense(1, activation='sigmoid')) # output layer
dense_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
dense_nn_fitted = dense_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
dense_nn.summary()
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 2ms/step - loss: 3.6366 - acc: 0.5451
# Epoch 2/100
# 18/18 [==============================] - 0s 2ms/step - loss: 1.0993 - acc: 0.6042
# Epoch 3/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6571 - acc: 0.6753
# Epoch 4/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.6705 - acc: 0.6771
# Epoch 5/100
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7329 - acc: 0.6163
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6764 - acc: 0.6684
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.6190 - acc: 0.6997
# Epoch 8/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.6537 - acc: 0.6771
# Epoch 9/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5689 - acc: 0.7066
# Epoch 10/100
# 18/18 [==============================] - 0s 4ms/step - loss: 0.5763 - acc: 0.7083
# Epoch 11/100
# ...

# %%
dense_nn.evaluate(X_test, Y_test)

# %% [markdown]
# Change the data source to Breast Cancer dataset * available in the source folder and make required changes

# %%
breast_cancer_df = pd.read_csv("breastcancer.csv", header=[0])

breast_cancer_df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
breast_cancer_df.drop(['id', 'Unnamed: 32'], axis=1, inplace=True)
breast_cancer_df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
breast_cancer_df['diagnosis'].replace(['M','B'], [1, 0], inplace=True)
breast_cancer_df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
breast_cancer_data = breast_cancer_df.values
breast_cancer_data.shape
# Out:
# (569, 31)

# %%
X_train1, X_test1, Y_train1, Y_test1 = train_test_split(breast_cancer_data[:,1:31], breast_cancer_data[:,0],
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
breast_cancer_nn = Sequential() # create model
breast_cancer_nn.add(Dense(120, input_dim=30, activation='relu')) # hidden layer
dense_nn.add(Dense(80, activation='relu')) # hidden layer
breast_cancer_nn.add(Dense(1, activation='sigmoid')) # output layer
breast_cancer_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
breast_cancer_nn_fitted = breast_cancer_nn.fit(X_train1, Y_train1, epochs=100,
                                     initial_epoch=0)
breast_cancer_nn.summary()
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 3ms/step - loss: 133.9844 - acc: 0.6174
# Epoch 2/100
# 14/14 [==============================] - 0s 4ms/step - loss: 37.2410 - acc: 0.2793
# Epoch 3/100
# 14/14 [==============================] - 0s 6ms/step - loss: 26.0073 - acc: 0.2958
# Epoch 4/100
# 14/14 [==============================] - 0s 4ms/step - loss: 11.8245 - acc: 0.3263
# Epoch 5/100
# 14/14 [==============================] - 0s 4ms/step - loss: 4.5774 - acc: 0.5915
# Epoch 6/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.6954 - acc: 0.7629
# Epoch 7/100
# 14/14 [==============================] - 0s 4ms/step - loss: 1.2183 - acc: 0.8099
# Epoch 8/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.9148 - acc: 0.8474
# Epoch 9/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6634 - acc: 0.8638
# Epoch 10/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6148 - acc: 0.8756
# ...

# %%
breast_cancer_nn.evaluate(X_test1, Y_test1)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3620 - acc: 0.8462
# [0.36199963092803955, 0.8461538553237915]

# %% [markdown]
# Normalize the data before feeding the data to the model.

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
breast_cancer_scaled = sc.fit_transform(breast_cancer_data)
breast_cancer_scaled[:1, :]
# Out:
# array([[ 1.29767572,  1.09706398, -2.07333501,  1.26993369,  0.9843749 ,
#          1.56846633,  3.28351467,  2.65287398,  2.53247522,  2.21751501,
#          2.25574689,  2.48973393, -0.56526506,  2.83303087,  2.48757756,
#         -0.21400165,  1.31686157,  0.72402616,  0.66081994,  1.14875667,
#          0.90708308,  1.88668963, -1.35929347,  2.30360062,  2.00123749,
#          1.30768627,  2.61666502,  2.10952635,  2.29607613,  2.75062224,
#          1.93701461]])

# %%
X_train1, X_test1, Y_train1, Y_test1 = train_test_split(breast_cancer_scaled[:,1:31], breast_cancer_data[:,0],
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
breast_cancer_scaled_nn = Sequential() # create model
breast_cancer_scaled_nn.add(Dense(120, input_dim=30, activation='relu')) # hidden layer
dense_nn.add(Dense(80, activation='relu')) # hidden layer
breast_cancer_scaled_nn.add(Dense(1, activation='sigmoid')) # output layer
breast_cancer_scaled_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
breast_cancer_scaled_nn_fitted = breast_cancer_scaled_nn.fit(X_train1, Y_train1, epochs=100,
                                     initial_epoch=0)
breast_cancer_scaled_nn.summary()
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 3ms/step - loss: 0.4142 - acc: 0.8944
# Epoch 2/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2070 - acc: 0.9531
# Epoch 3/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1456 - acc: 0.9624
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1192 - acc: 0.9624
# Epoch 5/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1039 - acc: 0.9718
# Epoch 6/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0928 - acc: 0.9742
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0845 - acc: 0.9765
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0771 - acc: 0.9836
# Epoch 9/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0718 - acc: 0.9836
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0667 - acc: 0.9836
# Epoch 11/100
# ...

# %%
breast_cancer_scaled_nn.evaluate(X_test1, Y_test1)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.2338 - acc: 0.9650
# [0.23375189304351807, 0.9650349617004395]

# %%
diabetes_scaled = sc.fit_transform(dataset)
diabetes_scaled.shape
# Out:
# (768, 9)

# %%
X_train2, X_test2, Y_train2, Y_test2 = train_test_split(diabetes_scaled[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)
diabetes_scaled_nn = Sequential() # create model
diabetes_scaled_nn.add(Dense(120, input_dim=8, activation='relu')) # hidden layer
dense_nn.add(Dense(80, activation='relu')) # hidden layer
diabetes_scaled_nn.add(Dense(1, activation='sigmoid')) # output layer
diabetes_scaled_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
diabetes_scaled_nn_fitted = diabetes_scaled_nn.fit(X_train2, Y_train2, epochs=100,
                                     initial_epoch=0)
diabetes_scaled_nn.summary()
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 3ms/step - loss: 0.6360 - acc: 0.6684
# Epoch 2/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5641 - acc: 0.7396
# Epoch 3/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5248 - acc: 0.7500
# Epoch 4/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5007 - acc: 0.7569
# Epoch 5/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4838 - acc: 0.7691
# Epoch 6/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4737 - acc: 0.7691
# Epoch 7/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4649 - acc: 0.7760
# Epoch 8/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4593 - acc: 0.7760
# Epoch 9/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4551 - acc: 0.7795
# Epoch 10/100
# 18/18 [==============================] - 0s 3ms/step - loss: 0.4525 - acc: 0.7830
# Epoch 11/100
# ...

# %%
diabetes_scaled_nn.evaluate(X_test2, Y_test2)
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 0.4826 - acc: 0.7760
# [0.48262012004852295, 0.7760416865348816]

# %%
from keras import Sequential
from keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import Dense
from keras.utils import to_categorical
from sklearn.feature_extraction.tests import test_image

# %% [markdown]
# Load Data

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# Display the first image in the training data

# %%
plt.imshow(train_images[0, :, :], cmap='gray')
plt.title('Ground Truth : {}'.format(train_labels[0]))
plt.show()

# %% [markdown]
# Process the data
# convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature

# %%
dimData = np.prod(train_images.shape[1:])
train_data = train_images.reshape(train_images.shape[0], dimData)
test_data = test_images.reshape(test_images.shape[0], dimData)

# %% [markdown]
# Convert data to float and scale values between 0 and 1

# %%
train_data = train_data.astype('float')
test_data = test_data.astype('float')

# scale data
train_data /= 255.0
test_data /= 255.0

# change the labels from integer to one-hot encoding
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

# %% [markdown]
# Create the network

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                    validation_data=(test_data, test_labels_one_hot))

[test_loss, test_acc] = model.evaluate(test_data, test_labels_one_hot)
print("Evaluation result on Test Data : Loss = {}, accuracy = {}".format(test_loss, test_acc))
# Out:
# Epoch 1/10
# 235/235 [==============================] - 7s 28ms/step - loss: 0.2644 - accuracy: 0.9234 - val_loss: 0.1174 - val_accuracy: 0.9634
# Epoch 2/10
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0899 - accuracy: 0.9728 - val_loss: 0.0876 - val_accuracy: 0.9723
# Epoch 3/10
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0579 - accuracy: 0.9821 - val_loss: 0.0715 - val_accuracy: 0.9768
# Epoch 4/10
# 235/235 [==============================] - 7s 32ms/step - loss: 0.0397 - accuracy: 0.9873 - val_loss: 0.0583 - val_accuracy: 0.9818
# Epoch 5/10
# 235/235 [==============================] - 7s 30ms/step - loss: 0.0246 - accuracy: 0.9923 - val_loss: 0.0659 - val_accuracy: 0.9805
# Epoch 6/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0190 - accuracy: 0.9941 - val_loss: 0.0670 - val_accuracy: 0.9805
# Epoch 7/10
# ...

# %% [markdown]
# Task 1
# Using the history object in the source code, plot the loss and accuracy for both training data and validation data

# %%
plt.plot(history.history['loss'], color="red")
plt.plot(history.history['accuracy'], color="green")
plt.plot(history.history['val_loss'], color="black")
plt.plot(history.history['val_accuracy'], color="brown")
plt.title('Loss & Accuracy')
plt.xlabel('Epoch')
plt.legend(['train loss', 'train acc', 'val loss', 'val acc'], loc='center right')
plt.show()

# %% [markdown]
# Task 2
# Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model on that single image in the test data.

# %%
random_index = np.random.randint(100)
predict_test = model.predict_classes(test_data[[random_index], :])
print("The prediction for the {44} image in the test dataset is: {3}".format(random_index, predict_test))

plt.imshow(test_images[random_index, :, :], cmap='gray')
plt.title('Ground Truth : {}'.format(test_labels[random_index]))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-934a0b3af733> in <module>
#       1 random_index = np.random.randint(100)
# ----> 2 predict_test = model.predict_classes(test_data[[random_index], :])
#       3 print("The prediction for the {44} image in the test dataset is: {3}".format(random_index, predict_test))
#       4
#       5 plt.imshow(test_images[random_index, :, :], cmap='gray')
#
# AttributeError: 'Sequential' object has no attribute 'predict_classes'

# %% [markdown]
# Task 3
# We had used 2 hidden layers and Relu activation. Try to change the number of hidden layer and the activation to tanh or sigmoid and see what happens

# %%
model2 = Sequential()
model2.add(Dense(256, activation='relu', input_shape=(dimData,)))
model2.add(Dense(128, activation='sigmoid'))
model2.add(Dense(10, activation='softmax'))

model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history2 = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                    validation_data=(test_data, test_labels_one_hot))

[test_loss2, test_acc2] = model2.evaluate(test_data, test_labels_one_hot)
print("Evaluation result on Test Data : Loss = {}, accuracy = {}".format(test_loss2, test_acc2))

plt.plot(history2.history['loss'], color="red")
plt.plot(history2.history['accuracy'], color="green")
plt.plot(history2.history['val_loss'], color="black")
plt.plot(history2.history['val_accuracy'], color="brown")
plt.title('Loss & Accuracy')
plt.legend(['train loss', 'train acc', 'val loss', 'val acc'], loc='center right')
plt.show()
# Out:
# Epoch 1/10
# 235/235 [==============================] - 7s 31ms/step - loss: 0.0088 - accuracy: 0.9971 - val_loss: 0.0775 - val_accuracy: 0.9809
# Epoch 2/10
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0840 - val_accuracy: 0.9806
# Epoch 3/10
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0114 - accuracy: 0.9961 - val_loss: 0.0881 - val_accuracy: 0.9797
# Epoch 4/10
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.1145 - val_accuracy: 0.9747
# Epoch 5/10
# 235/235 [==============================] - 7s 32ms/step - loss: 0.0075 - accuracy: 0.9974 - val_loss: 0.0788 - val_accuracy: 0.9822
# Epoch 6/10
# 235/235 [==============================] - 6s 28ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.0977 - val_accuracy: 0.9790
# Epoch 7/10
# ...

# %% [markdown]
# Task 4
# Run the same code without scaling the images, how the accuracy changes?

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

dimData = np.prod(train_images.shape[1:])
train_data = train_images.reshape(train_images.shape[0], dimData)
test_data = test_images.reshape(test_images.shape[0], dimData)

train_data = train_data.astype('float')
test_data = test_data.astype('float')

# change the labels from integer to one-hot encoding
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                    validation_data=(test_data, test_labels_one_hot))

[test_loss, test_acc] = model.evaluate(test_data, test_labels_one_hot)
print("Evaluation result on Test Data : Loss = {}, accuracy = {}".format(test_loss, test_acc))

plt.plot(history.history['loss'], color="red")
plt.plot(history.history['accuracy'], color="green")
plt.plot(history.history['val_loss'], color="black")
plt.plot(history.history['val_accuracy'], color="brown")
plt.title('Loss & Accuracy')
plt.legend(['train loss', 'train acc', 'val loss', 'val acc'], loc='center right')
plt.show()
# Out:
# Epoch 1/10
# 235/235 [==============================] - 11s 42ms/step - loss: 3.8506 - accuracy: 0.8924 - val_loss: 0.5815 - val_accuracy: 0.9362
# Epoch 2/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.3413 - accuracy: 0.9553 - val_loss: 0.3975 - val_accuracy: 0.9524
# Epoch 3/10
# 235/235 [==============================] - 7s 32ms/step - loss: 0.1605 - accuracy: 0.9724 - val_loss: 0.3544 - val_accuracy: 0.9577
# Epoch 4/10
# 235/235 [==============================] - 6s 26ms/step - loss: 0.1100 - accuracy: 0.9795 - val_loss: 0.3577 - val_accuracy: 0.9604
# Epoch 5/10
# 235/235 [==============================] - 8s 33ms/step - loss: 0.1026 - accuracy: 0.9811 - val_loss: 0.3186 - val_accuracy: 0.9636
# Epoch 6/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0855 - accuracy: 0.9835 - val_loss: 0.3378 - val_accuracy: 0.9636
# Epoch 7/10
# ...
